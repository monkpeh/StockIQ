# %% [markdown]
# # Api key

# %%
api_key = "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"

# %% [markdown]
# # Setup

# %%
# List of assets to analyze
assets = [
    "Apple (AAPL)",
    "Amazon (AMZN)",
    "Bitcoin (BTC-USD)",
    "Alphabet (GOOGL)",
    "Meta (META)",
    "Microsoft (MSFT)",
    "Nvidia (NVDA)",
    "S&P 500 index (SPY)",
    "Tesla (TSLA)"
]

# Define the start and end years for the analysis
start_year = 2022
end_year = 2023

# %%
# %pip install langchain-openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the LangChain OpenAI wrapper
from langchain_openai import ChatOpenAI
# Out:
# /Users/chukwuderaduru/Desktop/StockIQ/StockIQ/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Initialize the LLM
llm = ChatOpenAI(model = "gpt-4o",
                temperature = 0,
                api_key = api_key)

# %%
# Create the prompt to ask the llm
prompt = f"""
Can you provide a python code snippet using the yfinance library to download stock data.
The tickers are {assets} from {start_year} to {end_year}.   
"""

# %%
# Use the invoke method to get the response 
response = llm.invoke(prompt)

# %%
# Use the display function from IPython
from IPython.display import display, Markdown

display(Markdown(response.content))
# Out:
# Certainly! To download stock data using the `yfinance` library, you first need to ensure that you have the library installed. You can install it using pip if you haven't already:
#
# ```bash
# pip install yfinance
# ```
#
# Once you have `yfinance` installed, you can use the following Python code snippet to download the stock data for the specified tickers from 2022 to 2023:
#
# ```python
# import yfinance as yf
# import pandas as pd
#
# # Define the tickers
# tickers = ['AAPL', 'AMZN', 'BTC-USD', 'GOOGL', 'META', 'MSFT', 'NVDA', 'SPY', 'TSLA']
#
# # Define the start and end dates
# start_date = '2022-01-01'
# end_date = '2023-12-31'
#
# # Download the data
# data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker')
#
# # Display the data
# for ticker in tickers:
#     print(f"\nData for {ticker}:")
#     print(data[ticker].head())  # Display the first few rows of each ticker's data
# ```
#
# ...

# %%
def output():
    response = llm.invoke(prompt)
    display(Markdown(response.content))

# %% [markdown]
# # Fetch The Data

# %%
# %pip install yfinance
# Out:
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_x86_64.whl.metadata (60 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 25.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 35.0 MB/s eta 0:00:00
# ...
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 33.8 MB/s eta 0:00:00 0:00:01
# ...
#   Created wheel for peewee: filename=peewee-3.18.1-cp39-cp39-macosx_10_9_universal2.whl size=437461 sha256=6f45213aa1e37a4a61f917cc7f86b0036a93d2cedd4745b1853874c629bcdcf0
#   Stored in directory: /Users/chukwuderaduru/Library/Caches/pip/wheels/e7/09/87/1f1a87eb25af98d0a1f60ef184a9779d81c6a2e8d28bc67d7f
# ...

# %%
import yfinance as yf
import pandas as pd

# Define the tickers
tickers = ['AAPL', 'AMZN', 'BTC-USD', 'GOOGL', 'META', 'MSFT', 'NVDA', 'SPY', 'TSLA']
tickers.sort()

# Define the start and end years
start_date = '2022-01-01'
end_date = '2023-01-01'

# Download the stock data
data = yf.download(tickers, start=start_date, end=end_date)

# Display the first few rows of the data
data.head()
# Out:
# /var/folders/s6/2srg9sqd31z90wjwztx46qr00000gn/T/ipykernel_26682/3848205535.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  9 of 9 completed
# Price            Close                                                    \
# Ticker            AAPL        AMZN       BTC-USD       GOOGL        META
# Date
# 2022-01-01         NaN         NaN  47686.812500         NaN         NaN
# 2022-01-02         NaN         NaN  47345.218750         NaN         NaN
# 2022-01-03  178.645630  170.404495  46458.117188  144.127106  336.692871
# 2022-01-04  176.378342  167.522003  45897.574219  143.538666  334.693817
# 2022-01-05  171.686707  164.356995  43569.003906  136.953629  322.401306
#
# Price                                                            High  ...  \
# Ticker            MSFT       NVDA         SPY        TSLA        AAPL  ...
# ...

# %% [markdown]
# # Top trading KPIS

# %%
# Create the prompt for the LLM for the top 10 KPIS
prompt = f"""
Tell me the top 10 KPIS I could check fro the performance of the stocks, explain what they are and how to interpret.
tickers: {assets}
"""
output()
# Out:
# When evaluating the performance of stocks or other financial assets, there are several key performance indicators (KPIs) that investors commonly use. Here are the top 10 KPIs you might consider for the stocks and assets you've listed:
#
# 1. **Price-to-Earnings Ratio (P/E Ratio):**
#    - **What it is:** The P/E ratio measures a company's current share price relative to its per-share earnings. It is a valuation metric.
#    - **Interpretation:** A high P/E ratio could mean that a stock's price is high relative to earnings and possibly overvalued, or it could indicate that investors are expecting high growth rates in the future. Conversely, a low P/E might suggest undervaluation or lower growth expectations.
#
# 2. **Earnings Per Share (EPS):**
#    - **What it is:** EPS is the portion of a company's profit allocated to each outstanding share of common stock, indicating a company's profitability.
# ...

# %%
# Create the prompt for the top 10 KPIS with yfinance
prompt = f"""
Tell me the top 10 KPIS I could check for performance of the stocks with data available on finance. 
Explain the KPIS and how to interpret them.
Provide the python code to compute and visualize each of the KPIS.
Make sure the KPIS can be easily extracted to include in the following prompt for interpretation.
The structure should be:
1) What is the KPI and how to interpret
2) Code snippet for a function to visualize over time for each of the {assets} seperately for each kpi.
years of analysis are {start_year} to {end_year}
"""
output()
# Out:
# To evaluate the performance of stocks, you can use a variety of Key Performance Indicators (KPIs). Here are ten important KPIs, along with explanations and Python code snippets to compute and visualize them over time for the specified assets.
#
# ### 1) Price Change Percentage
# **What is it?**
# Price Change Percentage measures the percentage change in the stock price over a specific period. It helps investors understand how much the price has increased or decreased.
#
# **Interpretation:**
# A positive percentage indicates a price increase, while a negative percentage indicates a decrease.
#
# **Code Snippet:**
# ```python
# import yfinance as yf
# import matplotlib.pyplot as plt
#
# def plot_price_change_percentage(ticker, start_date='2022-01-01', end_date='2023-12-31'):
#     data = yf.download(ticker, start=start_date, end=end_date)
#     data['Price Change %'] = data['Adj Close'].pct_change() * 100
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 24.6 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]esources]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Relative Strength Index (RSI)

# %% [markdown]
# What is the KPI and how to interpret: RSI is a momentum oscillator that measures the speed and change of price movements. RSI values above 70 indicate overbought conditions, while values below 30 indicate oversold conditions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
def plot_rsi(ticker, start_date, end_date, window=14):
    stock = yf.Ticker(ticker)
    data = stock.history(start=start_date, end=end_date)
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    plt.figure(figsize=(10, 5))
    plt.plot(data.index, rsi, label='RSI', color='purple')
    plt.axhline(70, color='red', linestyle='--')
    plt.axhline(30, color='green', linestyle='--')
    plt.title(f'RSI of {ticker}')
    plt.xlabel('Date')
    plt.ylabel('RSI')
    plt.legend()
    plt.show()

for ticker in tickers:
    plot_rsi(ticker, '2022-01-01', '2023-12-31')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Bollinger Bands

# %%
def plot_bollinger_bands(ticker, start_date, end_date, window=20):
    stock = yf.Ticker(ticker)
    data = stock.history(start=start_date, end=end_date)
    data['Middle Band'] = data['Close'].rolling(window=window).mean()
    data['Upper Band'] = data['Middle Band'] + 2 * data['Close'].rolling(window=window).std()
    data['Lower Band'] = data['Middle Band'] - 2 * data['Close'].rolling(window=window).std()
    plt.figure(figsize=(10, 5))
    plt.plot(data.index, data['Close'], label='Closing Price')
    plt.plot(data.index, data['Middle Band'], label='Middle Band', color='blue')
    plt.plot(data.index, data['Upper Band'], label='Upper Band', color='red')
    plt.plot(data.index, data['Lower Band'], label='Lower Band', color='green')
    plt.title(f'Bollinger Bands of {ticker}')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

for ticker in tickers:
    plot_bollinger_bands(ticker, '2022-01-01', '2023-12-31')

# %% [markdown]
# ### Price-to-Earnings Ratio (P/E)

# %% [markdown]
# What is the KPI and how to interpret: The P/E ratio measures a company's current share price relative to its per-share earnings. A high P/E ratio may indicate that a stock is overvalued, or investors are expecting high growth rates in the future.

# %%
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

def plot_pe_ratio(tickers, start_date, end_date):
    plt.figure(figsize=(10, 5))

    for ticker in tickers:
        stock = yf.Ticker(ticker)
        try:
            data = stock.history(start=start_date, end=end_date)
            eps = stock.info.get('trailingEps')

            if eps is None or eps == 0:
                print(f"Warning: EPS for {ticker} is not available or zero. PE ratio can't be calculated.")
                continue

            pe_ratio = data['Close'] / eps
            plt.plot(data.index, pe_ratio, label=f'{ticker} PE Ratio')
        except KeyError as e:
            print(f"Error retrieving data for {ticker}: {e}")
        except Exception as e:
            print(f"An error occurred with ticker {ticker}: {e}")

    plt.title('PE Ratios of Selected Stocks')
    plt.xlabel('Date')
    plt.ylabel('PE Ratio')
    plt.gca().yaxis.set_major_locator(MultipleLocator(20))  # Set y-axis ticks at 20, 40, 60, etc.
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_pe_ratio(tickers, '2022-01-01', '2023-12-31')

# %% [markdown]
# ### Beta

# %% [markdown]
# What is the KPI and how to interpret: Beta measures a stock's volatility relative to the overall market. A beta greater than 1 indicates higher volatility than the market, while a beta less than 1 indicates lower volatility.

# %%
def plot_beta(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    try:
        data = stock.history(start=start_date, end=end_date)
        beta = stock.info.get['beta']

        if beta is None:
            print(f"Warning: Beta for {ticker} is not available.")
            return
        
        plt.figure(figsize=(10, 5))
        plt.plot(data.index, [beta] * len(data), label='Beta', color='black')
        plt.title(f'Beta of {ticker}')
        plt.xlabel('Date')
        plt.ylabel('Beta')
        plt.legend()
        plt.show()
    except KeyError as e:
        print(f"Error retrieving data for {ticker}: {e}")
    except Exception as e:
        print(f"An error occurred with ticker {ticker}: {e}")

for ticker in tickers:
    plot_beta(ticker, '2022-01-01', '2023-12-31')
# Out:
# An error occurred with ticker AAPL: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker AMZN: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker BTC-USD: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker GOOGL: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker META: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker MSFT: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker NVDA: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker SPY: 'builtin_function_or_method' object is not subscriptable
# An error occurred with ticker TSLA: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# ### MACD

# %% [markdown]
# The Moving Average Convergence Divergence (MACD) is a trend-following momentum indicator that shows the relationship between two moving averages of a stock's price. To calculate the MACD, you typically use the 12-day and 26-day exponential moving averages (EMAs), and also plot the signal line, which is a 9-day EMA of the MACD. A positive MACD indicates a positive momentum.

# %%
def plot_beta_comparison(tickers, start_date, end_date): 
    betas = {}
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        try:
            data = stock.history(start=start_date, end=end_date)
            beta = stock.info.get('beta')

            if beta is None:
                print(f"Warning: Beta for {ticker} is not available.")
                continue

            betas[ticker] = beta
        except KeyError as e:
            print(f"Error retrieving data for {ticker}: {e}")
        except Exception as e:
            print(f"An error occurred with ticker {ticker}: {e}")
    
    # Plotting the bar chart
    plt.figure(figsize=(10, 5))
    plt.bar(betas.keys(), betas.values(), color='blue')
    plt.title('Beta Comparison of Selected Stocks')
    plt.xlabel('Ticker')
    plt.ylabel('Beta')
    plt.tight_layout()
    plt.show()

plot_beta_comparison(tickers, '2022-01-01', '2023-12-31')
