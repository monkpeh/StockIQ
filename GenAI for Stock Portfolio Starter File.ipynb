# %% [markdown]
# # Api key

# %%
api_key = "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"

# %% [markdown]
# # Setup

# %%
# List of assets to analyze
assets = [
    "Apple (AAPL)",
    "Amazon (AMZN)",
    "Bitcoin (BTC-USD)",
    "Alphabet (GOOGL)",
    "Meta (META)",
    "Microsoft (MSFT)",
    "Nvidia (NVDA)",
    "S&P 500 index (SPY)",
    "Tesla (TSLA)"
]

# Define the start and end years for the analysis
start_year = 2022
end_year = 2023

# %%
# %pip install langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (0.3.22)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.64 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.3.65)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (1.86.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.3.45 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (4.12.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.64->langchain-openai) (2.11.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain-openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.64->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.64->langchain-openai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.64->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.64->langchain-openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.64->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.64->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.64->langchain-openai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the LangChain OpenAI wrapper
from langchain_openai import ChatOpenAI

# %%
# Initialize the LLM
llm = ChatOpenAI(model = "gpt-4o",
                temperature = 0,
                api_key = api_key)

# %%
# Create the prompt to ask the llm
prompt = f"""
Can you provide a python code snippet using the yfinance library to download stock data.
The tickers are {assets} from {start_year} to {end_year}.   
"""

# %%
# Use the invoke method to get the response 
response = llm.invoke(prompt)

# %%
# Use the display function from IPython
from IPython.display import display, Markdown

display(Markdown(response.content))
# Out:
# Certainly! To download stock data using the `yfinance` library, you first need to ensure that the library is installed. You can install it using pip if you haven't already:
#
# ```bash
# pip install yfinance
# ```
#
# Once you have `yfinance` installed, you can use the following Python code snippet to download the stock data for the specified tickers from 2022 to 2023:
#
# ```python
# import yfinance as yf
# import pandas as pd
#
# # Define the tickers
# tickers = ['AAPL', 'AMZN', 'BTC-USD', 'GOOGL', 'META', 'MSFT', 'NVDA', 'SPY', 'TSLA']
#
# # Define the start and end dates
# start_date = '2022-01-01'
# end_date = '2023-12-31'
#
# # Download the data
# data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker')
#
# # Display the data
# for ticker in tickers:
#     print(f"\nData for {ticker}:")
#     print(data[ticker].head())  # Display the first few rows of each ticker's data
# ```
#
# This code snippet will download the historical stock data for each of the specified tickers from January 1, 2022, to December 31, 2023. The data is grouped by ticker, and the first few rows of each ticker's data are printed to the console. You can adjust the `start_date` and `end_date` variables as needed to fit your specific requirements.

# %%
def output():
    response = llm.invoke(prompt)
    display(Markdown(response.content))

# %% [markdown]
# # Fetch The Data

# %%
# %pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (0.2.44)
# Requirement already satisfied: pandas>=1.3.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chukwuderaduru/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->yfinance) (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd

# Define the tickers
tickers = ['AAPL', 'AMZN', 'BTC-USD', 'GOOGL', 'META', 'MSFT', 'NVDA', 'SPY', 'TSLA']
tickers.sort()

# Define the start and end years
start_date = '2022-01-01'
end_date = '2023-01-01'

# Download the stock data
data = yf.download(tickers, start=start_date, end=end_date)

# Display the first few rows of the data
data.head()
# Out:
# Failed to get ticker 'AMZN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GOOGL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NVDA' reason: Expecting value: line 1 column 1 (char 0)
# [                       0%                       ]Failed to get ticker 'META' reason: Expecting value: line 1 column 1 (char 0)
# [***********           22%                       ]  2 of 9 completedFailed to get ticker 'BTC-USD' reason: Expecting value: line 1 column 1 (char 0)
# [***********           22%                       ]  2 of 9 completedFailed to get ticker 'MSFT' reason: Expecting value: line 1 column 1 (char 0)
# [********************* 44%                       ]  4 of 9 completedFailed to get ticker 'TSLA' reason: Expecting value: line 1 column 1 (char 0)
# [**********************56%**                     ]  5 of 9 completedFailed to get ticker 'SPY' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  9 of 9 completed
#
# 9 Failed downloads:
# ['AMZN', 'GOOGL', 'NVDA', 'META', 'BTC-USD', 'MSFT', 'TSLA', 'SPY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['AAPL']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Adj Close, AMZN), (Adj Close, BTC-USD), (Adj Close, GOOGL), (Adj Close, META), (Adj Close, MSFT), (Adj Close, NVDA), (Adj Close, SPY), (Adj Close, TSLA), (Close, AAPL), (Close, AMZN), (Close, BTC-USD), (Close, GOOGL), (Close, META), (Close, MSFT), (Close, NVDA), (Close, SPY), (Close, TSLA), (High, AAPL), (High, AMZN), (High, BTC-USD), (High, GOOGL), (High, META), (High, MSFT), (High, NVDA), (High, SPY), (High, TSLA), (Low, AAPL), (Low, AMZN), (Low, BTC-USD), (Low, GOOGL), (Low, META), (Low, MSFT), (Low, NVDA), (Low, SPY), (Low, TSLA), (Open, AAPL), (Open, AMZN), (Open, BTC-USD), (Open, GOOGL), (Open, META), (Open, MSFT), (Open, NVDA), (Open, SPY), (Open, TSLA), (Volume, AAPL), (Volume, AMZN), (Volume, BTC-USD), (Volume, GOOGL), (Volume, META), (Volume, MSFT), (Volume, NVDA), (Volume, SPY), (Volume, TSLA)]
# Index: []
#
# [0 rows x 54 columns]

# %% [markdown]
# # Top trading KPIS

# %%
# Create the prompt for the LLM for the top 10 KPIS
prompt = f"""
Tell me the top 10 KPIS I could check fro the performance of the stocks, explain what they are and how to interpret.
tickers: {assets}
"""
output()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # Create the prompt for the LLM for the top 10 KPIS
#       2 prompt = f"""
#       3 Tell me the top 10 KPIS I could check fro the performance of the stocks, explain what they are and how to interpret.
# ----> 4 tickers: {assets}
#       5 """
#       6 output()
#
# NameError: name 'assets' is not defined

# %%
# Create the prompt for the top 10 KPIS with yfinance
prompt = f"""
Tell me the top 10 KPIS I could check for performance of the stocks with data available on finance. 
Explain the KPIS and how to interpret them.
Provide the python code to compute and visualize each of the KPIS.
Make sure the KPIS can be easily extracted to include in the following prompt.
# Out:
#   Cell In[23], line 6
#     Make sure the KPIS can be easily extracted to include in the following prompt.
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal
